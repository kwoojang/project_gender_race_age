# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import os
from PIL import Image

# %%
data = os.listdir('./UTKFace/')
len(data)
# Out:
# 23708

# %%
data = os.listdir('./UTKFace/')
df = pd.DataFrame(data=data, columns=['file_name'])
df
# Out:
#                                     file_name
# 0      100_0_0_20170112213500903.jpg.chip.jpg
# 1      100_0_0_20170112215240346.jpg.chip.jpg
# 2      100_1_0_20170110183726390.jpg.chip.jpg
# 3      100_1_0_20170112213001988.jpg.chip.jpg
# 4      100_1_0_20170112213303693.jpg.chip.jpg
# ...                                       ...
# 23703    9_1_3_20161220222856346.jpg.chip.jpg
# 23704    9_1_3_20170104222949455.jpg.chip.jpg
# 23705    9_1_4_20170103200637399.jpg.chip.jpg
# 23706    9_1_4_20170103200814791.jpg.chip.jpg
# 23707    9_1_4_20170103213057382.jpg.chip.jpg
#
# [23708 rows x 1 columns]

# %%
drop_list = os.listdir('./0.strange/')
drop_list
# Out:
# ['111_1_0_20170120134646399.jpg.chip.jpg',
#  '11_1_0_20170117133441179.jpg.chip.jpg',
#  '16_1_0_20170113210605072.jpg.chip.jpg',
#  '17_0_1_20170116205618568.jpg.chip.jpg',
#  '17_1_0_20170113210605193.jpg.chip.jpg',
#  '17_1_3_20170104222038870.jpg.chip.jpg',
#  '18_0_1_20170113175821404.jpg.chip.jpg',
#  '1_0_0_20170109193052283.jpg.chip.jpg',
#  '1_0_0_20170109194120301.jpg.chip.jpg',
#  '1_1_0_20170109190852630.jpg.chip.jpg',
#  '1_1_0_20170109194452834.jpg.chip.jpg',
#  '1_1_4_20170109194502921.jpg.chip.jpg',
#  '20_0_3_20170117151020539.jpg.chip.jpg',
#  '20_1_3_20170119180826861.jpg.chip.jpg',
#  '21_0_0_20170117193719188.jpg.chip.jpg',
#  '21_0_4_20161223214802865.jpg.chip.jpg',
#  '21_0_4_20161223214813672.jpg.chip.jpg',
#  '21_0_4_20161223214820169.jpg.chip.jpg',
#  '21_0_4_20161223214821265.jpg.chip.jpg',
#  '21_0_4_20161223214825003.jpg.chip.jpg',
#  '21_0_4_20161223214826657.jpg.chip.jpg',
#  '21_0_4_20161223214827816.jpg.chip.jpg',
# ...

# %%
drop_idx = []
for drop_name in drop_list :
    idx = df[df['file_name'] == drop_name].index[0]
    drop_idx.append(idx)
drop_idx
# Out:
# [180,
#  241,
#  996,
#  1099,
#  1153,
#  1183,
#  1243,
#  1630,
#  1640,
#  2261,
#  2343,
#  2683,
#  2767,
#  2942,
#  2999,
#  3063,
#  3066,
#  3067,
#  3068,
#  3070,
#  3071,
#  3072,
#  3073,
#  3074,
#  3075,
#  3076,
#  3077,
#  3078,
#  3079,
#  3081,
#  3082,
#  3114,
#  3418,
#  3436,
#  3643,
#  3761,
#  3776,
#  3808,
#  3828,
#  3849,
#  3888,
#  4262,
#  4309,
#  4398,
#  4400,
#  5273,
#  5275,
#  5283,
#  5771,
#  5775,
#  5776,
#  5780,
#  5783,
#  5786,
#  5787,
#  5790,
#  5794,
#  5795,
#  5798,
#  5799,
#  5800,
#  5803,
#  5804,
#  5805,
#  5808,
#  5880,
#  5964,
#  5968,
#  5971,
#  5980,
#  6220,
#  6230,
#  6300,
#  6306,
#  6354,
#  6503,
#  6534,
#  6675,
#  6681,
#  6744,
#  6745,
#  6748,
#  6749,
#  6757,
#  7067,
#  7068,
#  7099,
#  7624,
#  8128,
#  8158,
#  8190,
#  8345,
#  8371,
#  8563,
#  8564,
#  8786,
#  8829,
#  9017,
#  9187,
#  9839,
#  10308,
#  10617,
#  10722,
#  10752,
#  10806,
#  10849,
#  10850,
#  10856,
#  11262,
#  11311,
# ...

# %%
print(len(drop_list))
len(drop_list) == len(drop_idx)
# Out:
# 189
# True

# %%
df
# Out:
#                                     file_name
# 0      100_0_0_20170112213500903.jpg.chip.jpg
# 1      100_0_0_20170112215240346.jpg.chip.jpg
# 2      100_1_0_20170110183726390.jpg.chip.jpg
# 3      100_1_0_20170112213001988.jpg.chip.jpg
# 4      100_1_0_20170112213303693.jpg.chip.jpg
# ...                                       ...
# 23703    9_1_3_20161220222856346.jpg.chip.jpg
# 23704    9_1_3_20170104222949455.jpg.chip.jpg
# 23705    9_1_4_20170103200637399.jpg.chip.jpg
# 23706    9_1_4_20170103200814791.jpg.chip.jpg
# 23707    9_1_4_20170103213057382.jpg.chip.jpg
#
# [23708 rows x 1 columns]

# %%
df.drop(index=drop_idx, inplace=True)
df
# Out:
#                                     file_name
# 0      100_0_0_20170112213500903.jpg.chip.jpg
# 1      100_0_0_20170112215240346.jpg.chip.jpg
# 2      100_1_0_20170110183726390.jpg.chip.jpg
# 3      100_1_0_20170112213001988.jpg.chip.jpg
# 4      100_1_0_20170112213303693.jpg.chip.jpg
# ...                                       ...
# 23703    9_1_3_20161220222856346.jpg.chip.jpg
# 23704    9_1_3_20170104222949455.jpg.chip.jpg
# 23705    9_1_4_20170103200637399.jpg.chip.jpg
# 23706    9_1_4_20170103200814791.jpg.chip.jpg
# 23707    9_1_4_20170103213057382.jpg.chip.jpg
#
# [23519 rows x 1 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                                     file_name
# 0      100_0_0_20170112213500903.jpg.chip.jpg
# 1      100_0_0_20170112215240346.jpg.chip.jpg
# 2      100_1_0_20170110183726390.jpg.chip.jpg
# 3      100_1_0_20170112213001988.jpg.chip.jpg
# 4      100_1_0_20170112213303693.jpg.chip.jpg
# ...                                       ...
# 23514    9_1_3_20161220222856346.jpg.chip.jpg
# 23515    9_1_3_20170104222949455.jpg.chip.jpg
# 23516    9_1_4_20170103200637399.jpg.chip.jpg
# 23517    9_1_4_20170103200814791.jpg.chip.jpg
# 23518    9_1_4_20170103213057382.jpg.chip.jpg
#
# [23519 rows x 1 columns]

# %%
df['age'] = df['file_name'].apply(lambda x : int(x.split('_')[0]))
df['gender'] = df['file_name'].apply(lambda x : int(x.split('_')[1]))

# %%
df['gender'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['race'] = df['file_name'].apply(lambda x : x.split('_')[2])

# %%
df['race'].unique()
# Out:
# array(['0', '2', '1', '3', '4', '20170109142408075.jpg.chip.jpg',
#        '20170109150557335.jpg.chip.jpg'], dtype=object)

# %%
df = df[(df['race'] == '0') | (df['race'] == '1') | (df['race'] == '2')].reset_index(drop=True)

# %%
df
# Out:
#                                     file_name  age  gender race
# 0      100_0_0_20170112213500903.jpg.chip.jpg  100       0    0
# 1      100_0_0_20170112215240346.jpg.chip.jpg  100       0    0
# 2      100_1_0_20170110183726390.jpg.chip.jpg  100       1    0
# 3      100_1_0_20170112213001988.jpg.chip.jpg  100       1    0
# 4      100_1_0_20170112213303693.jpg.chip.jpg  100       1    0
# ...                                       ...  ...     ...  ...
# 17902    9_1_2_20161219190524395.jpg.chip.jpg    9       1    2
# 17903    9_1_2_20161219192342173.jpg.chip.jpg    9       1    2
# 17904    9_1_2_20161219204347420.jpg.chip.jpg    9       1    2
# 17905    9_1_2_20170102235115156.jpg.chip.jpg    9       1    2
# 17906    9_1_2_20170104020210475.jpg.chip.jpg    9       1    2
#
# [17907 rows x 4 columns]

# %%
df['race'] = df['race'].apply(lambda x : int(x))
df
# Out:
#                                     file_name  age  gender  race
# 0      100_0_0_20170112213500903.jpg.chip.jpg  100       0     0
# 1      100_0_0_20170112215240346.jpg.chip.jpg  100       0     0
# 2      100_1_0_20170110183726390.jpg.chip.jpg  100       1     0
# 3      100_1_0_20170112213001988.jpg.chip.jpg  100       1     0
# 4      100_1_0_20170112213303693.jpg.chip.jpg  100       1     0
# ...                                       ...  ...     ...   ...
# 17902    9_1_2_20161219190524395.jpg.chip.jpg    9       1     2
# 17903    9_1_2_20161219192342173.jpg.chip.jpg    9       1     2
# 17904    9_1_2_20161219204347420.jpg.chip.jpg    9       1     2
# 17905    9_1_2_20170102235115156.jpg.chip.jpg    9       1     2
# 17906    9_1_2_20170104020210475.jpg.chip.jpg    9       1     2
#
# [17907 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17907 entries, 0 to 17906
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   file_name  17907 non-null  object
#  1   age        17907 non-null  int64
#  2   gender     17907 non-null  int64
#  3   race       17907 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 559.7+ KB

# %%
plt.pie(list(df['gender'].value_counts()), labels=['Men', 'Women'], 
       autopct='%.1f%%', explode=[0.01, 0.01], counterclock=False, shadow=True)
plt.title('Gender')
plt.show()

# %%
df['age_cat'] = df['age'].apply(lambda x : x // 10)
df
# Out:
#                                     file_name  age  gender  race  age_cat
# 0      100_0_0_20170112213500903.jpg.chip.jpg  100       0     0       10
# 1      100_0_0_20170112215240346.jpg.chip.jpg  100       0     0       10
# 2      100_1_0_20170110183726390.jpg.chip.jpg  100       1     0       10
# 3      100_1_0_20170112213001988.jpg.chip.jpg  100       1     0       10
# 4      100_1_0_20170112213303693.jpg.chip.jpg  100       1     0       10
# ...                                       ...  ...     ...   ...      ...
# 17902    9_1_2_20161219190524395.jpg.chip.jpg    9       1     2        0
# 17903    9_1_2_20161219192342173.jpg.chip.jpg    9       1     2        0
# 17904    9_1_2_20161219204347420.jpg.chip.jpg    9       1     2        0
# 17905    9_1_2_20170102235115156.jpg.chip.jpg    9       1     2        0
# 17906    9_1_2_20170104020210475.jpg.chip.jpg    9       1     2        0
#
# [17907 rows x 5 columns]

# %%
mapper = {0 : '<20',
          1 : '<20',
          2 : '20',
          3 : '30',
          4 : '40',
          5 : '50',
          6 : '60',
          7 : '70',
          8 : '80+',
          9 : '80+',
          10 : '80+',
          11 : '80+'}

# %%
df['age_cat'] = df['age_cat'].map(mapper)
df
# Out:
#                                     file_name  age  gender  race age_cat
# 0      100_0_0_20170112213500903.jpg.chip.jpg  100       0     0     80+
# 1      100_0_0_20170112215240346.jpg.chip.jpg  100       0     0     80+
# 2      100_1_0_20170110183726390.jpg.chip.jpg  100       1     0     80+
# 3      100_1_0_20170112213001988.jpg.chip.jpg  100       1     0     80+
# 4      100_1_0_20170112213303693.jpg.chip.jpg  100       1     0     80+
# ...                                       ...  ...     ...   ...     ...
# 17902    9_1_2_20161219190524395.jpg.chip.jpg    9       1     2     <20
# 17903    9_1_2_20161219192342173.jpg.chip.jpg    9       1     2     <20
# 17904    9_1_2_20161219204347420.jpg.chip.jpg    9       1     2     <20
# 17905    9_1_2_20170102235115156.jpg.chip.jpg    9       1     2     <20
# 17906    9_1_2_20170104020210475.jpg.chip.jpg    9       1     2     <20
#
# [17907 rows x 5 columns]

# %%
plt.pie(list(df['age_cat'].value_counts()), labels=list(df['age_cat'].value_counts().index), 
       autopct='%.1f%%', explode=([0.01] * df['age_cat'].nunique()), counterclock=False, shadow=True)
plt.title('Age')
plt.show()

# %%
plt.pie(list(df['race'].value_counts()), labels=['White', 'Black', 'Asian'], 
       autopct='%.1f%%', explode=([0.01] * df['race'].nunique()), counterclock=False, shadow=True)
plt.title('Race')
plt.show()

# %%
df[df['race'] == 2]
# Out:
#                                     file_name  age  gender  race age_cat
# 8      100_1_2_20170105174847679.jpg.chip.jpg  100       1     2     80+
# 9      100_1_2_20170112213615815.jpg.chip.jpg  100       1     2     80+
# 10     100_1_2_20170112222336458.jpg.chip.jpg  100       1     2     80+
# 12     101_1_2_20170105174739309.jpg.chip.jpg  101       1     2     80+
# 13     103_0_2_20170112213001988.jpg.chip.jpg  103       0     2     80+
# ...                                       ...  ...     ...   ...     ...
# 17902    9_1_2_20161219190524395.jpg.chip.jpg    9       1     2     <20
# 17903    9_1_2_20161219192342173.jpg.chip.jpg    9       1     2     <20
# 17904    9_1_2_20161219204347420.jpg.chip.jpg    9       1     2     <20
# 17905    9_1_2_20170102235115156.jpg.chip.jpg    9       1     2     <20
# 17906    9_1_2_20170104020210475.jpg.chip.jpg    9       1     2     <20
#
# [3425 rows x 5 columns]

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
rus = RandomUnderSampler()

df_under, data_label = rus.fit_resample(df, df['race'])

# %%
df_under = pd.DataFrame(data=df_under, columns=df.columns).reset_index(drop=True)
df_under
# Out:
#                                    file_name  age  gender  race age_cat
# 0      56_1_0_20170117172544019.jpg.chip.jpg   56       1     0      50
# 1      50_0_0_20170104212134308.jpg.chip.jpg   50       0     0      50
# 2      45_0_0_20170111204133863.jpg.chip.jpg   45       0     0      40
# 3      27_0_0_20170114034255912.jpg.chip.jpg   27       0     0      20
# 4      26_0_0_20170105183712607.jpg.chip.jpg   26       0     0      20
# ...                                      ...  ...     ...   ...     ...
# 10270   9_1_2_20161219190524395.jpg.chip.jpg    9       1     2     <20
# 10271   9_1_2_20161219192342173.jpg.chip.jpg    9       1     2     <20
# 10272   9_1_2_20161219204347420.jpg.chip.jpg    9       1     2     <20
# 10273   9_1_2_20170102235115156.jpg.chip.jpg    9       1     2     <20
# 10274   9_1_2_20170104020210475.jpg.chip.jpg    9       1     2     <20
#
# [10275 rows x 5 columns]

# %%
plt.pie(list(df_under['race'].value_counts()), labels=['White', 'Black', 'Asian'], 
       autopct='%.1f%%', explode=([0.01] * df_under['race'].nunique()), counterclock=False, shadow=True)
plt.title('Race')
plt.show()

# %%
plt.pie(list(df_under['gender'].value_counts()), labels=['Men', 'Women'], 
       autopct='%.1f%%', explode=[0.01, 0.01], counterclock=False, shadow=True)
plt.title('Gender')
plt.show()

# %%
plt.pie(list(df_under['age_cat'].value_counts()), labels=list(df_under['age_cat'].value_counts().index), 
       autopct='%.1f%%', explode=([0.01] * df_under['age_cat'].nunique()), counterclock=False, shadow=True)
plt.title('Age')
plt.show()

# %%
df_under[df_under['age_cat'] == '70']
# Out:
#                                    file_name  age  gender  race age_cat
# 28     78_0_0_20170117184536534.jpg.chip.jpg   78       0     0      70
# 49     71_1_0_20170110141059193.jpg.chip.jpg   71       1     0      70
# 75     76_1_0_20170110182941342.jpg.chip.jpg   76       1     0      70
# 113    73_0_0_20170120225937921.jpg.chip.jpg   73       0     0      70
# 154    75_0_0_20170111202241586.jpg.chip.jpg   75       0     0      70
# ...                                      ...  ...     ...   ...     ...
# 10122  79_0_2_20170105174927254.jpg.chip.jpg   79       0     2      70
# 10123  79_0_2_20170112223937939.jpg.chip.jpg   79       0     2      70
# 10124  79_0_2_20170112224730972.jpg.chip.jpg   79       0     2      70
# 10125  79_0_2_20170116194001100.jpg.chip.jpg   79       0     2      70
# 10126  79_1_2_20170110175752735.jpg.chip.jpg   79       1     2      70
#
# [297 rows x 5 columns]

# %%
df_under.to_csv('./data01_undersampled.csv', index=False)
